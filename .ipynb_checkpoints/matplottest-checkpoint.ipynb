# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
sp = np.fft.fft(np.sin(377t))
freq = np.fft.fftfreq(t.shape[-1])
plt.plot(freq, sp.real, freq, sp.imag)
plt.show()

# %%
t = np.arange(0,1,0.01)
freq = np.fft.fftfreq(t.shape[-1])
sp = np.fft.fft(100*np.cos(np.pi*2*t))


#plt.hist( sp.real,30, normed=1, facecolor='g', alpha=0.75)
#plt.plot(freq,sp.real,freq,sp.imag)
plt.bar(freq,sp.real,edgecolor='#d62728',color='#111111')

plt.show()

# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0,1,0.1)
data = np.cos(np.pi*2*t)
ps = np.abs(np.fft.fft(data))**2
time_step = 1 / 30
freqs = np.fft.fftfreq(t.shape[-1])
idx = np.argsort(freqs)

plt.plot(freqs[idx], ps[idx])
plt.show()

# %%
#http://stackoverflow.com/questions/15382076/plotting-power-spectrum-in-python
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0,1,0.01)
data = np.cos(60*2*np.pi*t)
#data = np.random.rand(301) - 0.5
ps = np.abs(np.fft.fft(data))**2

time_step = 1 /100
freqs = np.fft.fftfreq(data.size,time_step)
idx = np.argsort(freqs)

plt.plot(freqs[idx], ps[idx],dashes=[30, 5, 10, 5],label='ch1')

plt.legend(loc='lower right')

plt.show()

# %%
import numpy as np
#import pylab as pl
rate = 30
time=1
n=rate*time
t = np.arange(0, time, 1/rate)
data = np.sin(2*np.pi*t) #+ 2*np.sin(2*np.pi*7*t)
p = np.abs(np.fft.rfft(data))/n*2
f = np.linspace(0, rate/2, len(p))
#pl.plot(f, np.abs(np.fft.rfft(x)))
plt.bar(f,p,width=0.1,)
plt.xticks(f)
plt.yticks(np.arange(0,int(max(p))+1,0.5))
plt.show()

# %%
from bqplot import pyplot as pl

#pl.figure()
pp =pl.plot(t,x,display_legend=True, line_width=3, opacities=[0.2], labels=["1hz"])
pl.show()
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
# Out:
# array([-14.95016611, -14.85049834, -14.75083056, -14.65116279,
#        -14.55149502, -14.45182724, -14.35215947, -14.25249169,
#        -14.15282392, -14.05315615, -13.95348837, -13.8538206 ,
#        -13.75415282, -13.65448505, -13.55481728, -13.4551495 ,
#        -13.35548173, -13.25581395, -13.15614618, -13.05647841,
#        -12.95681063, -12.85714286, -12.75747508, -12.65780731,
#        -12.55813953, -12.45847176, -12.35880399, -12.25913621,
#        -12.15946844, -12.05980066, -11.96013289, -11.86046512,
#        -11.76079734, -11.66112957, -11.56146179, -11.46179402,
#        -11.36212625, -11.26245847, -11.1627907 , -11.06312292,
#        -10.96345515, -10.86378738, -10.7641196 , -10.66445183,
#        -10.56478405, -10.46511628, -10.3654485 , -10.26578073,
#        -10.16611296, -10.06644518,  -9.96677741,  -9.86710963,
#         -9.76744186,  -9.66777409,  -9.56810631,  -9.46843854,
#         -9.36877076,  -9.26910299,  -9.16943522,  -9.06976744,
#         -8.97009967,  -8.87043189,  -8.77076412,  -8.67109635,
#         -8.57142857,  -8.4717608 ,  -8.37209302,  -8.27242525,
#         -8.17275748,  -8.0730897 ,  -7.97342193,  -7.87375415,
#         -7.77408638,  -7.6744186 ,  -7.57475083,  -7.47508306,
#         -7.37541528,  -7.27574751,  -7.17607973,  -7.07641196,
#         -6.97674419,  -6.87707641,  -6.77740864,  -6.67774086,
#         -6.57807309,  -6.47840532,  -6.37873754,  -6.27906977,
# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

mu = 200
sigma = 25
x = np.random.normal(mu, sigma, size=4000)

fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(8,4 ))

ax0.hist(x, 20, normed=1, histtype='stepfilled', facecolor='g', alpha=0.75)
ax0.set_title('stepfilled')

# Create a histogram by providing the bin edges (unequally spaced).
bins = [100, 150, 180, 195, 205, 220, 250, 300]
ax1.hist(x, bins, normed=1, histtype='bar', rwidth=0.8)
ax1.set_title('unequal bins')

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# example data
x = np.arange(0.1, 4, 0.5)
y = np.exp(-x)

# example error bar values that vary with x-position
error = 0.1 + 0.2 * x


fig, (ax0, ax1) = plt.subplots(nrows=2)


ax0.errorbar(x, y, yerr=error, fmt='-o')
ax0.set_title('variable, symmetric error')

# error bar values w/ different -/+ errors that
# also vary with the x-position
lower_error = 0.4 * error
upper_error = error
asymmetric_error = [lower_error, upper_error]

ax1.errorbar(x, y, xerr=asymmetric_error, fmt='o')
ax1.set_title('variable, asymmetric error')
ax1.set_yscale('log')
plt.show()

# %%
import pandas as pd

cvs = pd.DataFrame({'births': {0: 7065, 1: 2604, 2: 2003, 3: 1939, 4: 1746},
 'gender': {0: 'F', 1: 'M', 2: 'F', 3: 'M', 4: 'F'},
 'name': {0: 'mary', 1: 'anna', 2: 'emma', 3: 'elizabeth', 4: 'minnie'},
 'year': {0: 1880, 1: 1880, 2: 1880, 3: 1880, 4: 1880}})

cvs.index.name=222
cvs.index.
# Out:
# '222,births,gender,name,year\n0,7065,F,mary,1880\n1,2604,M,anna,1880\n2,2003,F,emma,1880\n3,1939,M,elizabeth,1880\n4,1746,F,minnie,1880\n'

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import time
import os
import sys
import readline
import glob

dirPath=os.path.dirname(os.path.abspath(sys.argv[0]))

#autocomplete
def pathCompleter(text,state):
    line   = readline.get_line_buffer().split()
    return [x for x in glob.glob(text+'*')][state]
readline.set_completer_delims('\t')
readline.parse_and_bind("tab: complete")
readline.set_completer(pathCompleter)

#show dir filename
print("dir's csv file: \n")
for x in glob.glob(dirPath+'/*.csv'):
    print(os.path.basename(x))
filename=input("\nPlease input cvs filename :")
print (filename)




filePath=os.path.join(dirPath,filename)
csv=pd.read_csv(filePath)
data=np.array(csv)
time=data[:,0]


fig, (ax0, ax1) = plt.subplots(nrows=2)

ax0.plot(time, data[:,1]*5/1024)
ax0.set_ylabel('voltage(V)')
ax0.set_xlabel('time(n)')
n=data.shape[0]

rate=float(csv.columns[0])
p = np.abs(np.fft.fft(data[:,1]))/(n^2)
f = np.linspace(0, rate/2, len(p))

ax1.bar(f[:10],p[:10])
#ax1.set_xticks(f)
#ax1.set_yticks(np.arange(0,int(max(p))+1,0.5))
plt.show()
# Out:
# dir's csv file:
#
# 20170509_232540.csv
# 20170509_232939.csv
#
# Please input cvs filename :/Users/leason/Documents/raspy/20170513_143920.csv
# /Users/leason/Documents/raspy/20170513_143920.csv

# %%
data.shape
# Out:
# (3000, 2)

# %%
/Users/leason/Documents/raspy/20170513_143920.csv

# %%
float(csv.columns[0])/2
# Out:
# 37899.4241102624
